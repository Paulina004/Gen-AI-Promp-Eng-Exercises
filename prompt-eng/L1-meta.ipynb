# %% [markdown]
# # Meta Prompting (Level 1 Automation)
#
# Meta prompting is an advanced technique in prompt engineering that emphasizes the structural and syntactical organization of tasks and problems rather than focusing on their specific content. The objective is to create a more abstract, form-driven way of engaging with large language models (LLMs), highlighting patterns and structure over traditional content-focused methods.
#
# As outlined by [Zhang et al. (2024)](https://arxiv.org/abs/2311.11482), the defining features of meta prompting include:
#
# * Structure-Oriented: Prioritizes the organization and pattern of problems and solutions instead of specific content.
# * Syntax-Guided: Leverages syntax as a template to shape the expected responses or solutions.
# * Abstract Frameworks: Uses abstract examples as blueprints, demonstrating the structure of tasks without relying on concrete details.
# * Domain Versatility: Can be applied across multiple fields, offering structured solutions to diverse problem types.
# * Categorical Approach: Draws on type theory to organize and categorize components logically, enhancing prompt coherence and precision.

# %% [markdown]
# # Level 1 Automation Features & Limitations
#
# - **Lack of Context Retention** – Each prompt may not retain the context from the previous one, meaning some details might be missed.
# - **Over-Specification Risk** – Overly rigid constraints might limit creative and diverse responses.
# - **Assumption Dependency** – The effectiveness depends on assumed knowledge specific to the use case and requirement analysis.
# - **Complexity Management** – An extra layer of prompting may lead to convoluted or impractical responses.
# - **Iteration Overhead** – Refining prompts iteratively to get the desired output is more cost inefficient than Level 0 Automation (no prompt refinement).

# %% [markdown]
# ## Running this code on MyBind.org
#
# Note: remember that you will need to **adjust CONFIG** with **proper URL and API_KEY**!
#
# [![Binder](https://mybinder.org/badge_logo.svg)](https://mybinder.org/v2/gh/GenILab-FAU/prompt-eng/HEAD?urlpath=%2Fdoc%2Ftree%2Fprompt-eng%2Fmeta.ipynb)

# %%
##
## META PROMPTING (L1)
##
import csv
import time as timer
from _pipeline import create_payload, model_req
MODEL_PRESET = "qwen2.5:32b"


#### (1) Adjust the inbounding  Prompt, simulating inbounding requests from users or other systems
MESSAGE = """An AI-powered Discord chatbot to serve as a learning companion in a classroom. 
The bot will act as a study buddy by handling Q&A, explanations, and study tips. 
It should leverage natural language understanding and domain-specific knowledge to assist students. 
The bot must also be designed to prevent students from using it for cheating."""

#### (2) Adjust the Prompt Engineering Technique to be applied, simulating Workflow Templates
PROMPT1 = f"""Generate the best possible prompt for an LLM to perform a requirement analysis of the following use case: <{MESSAGE}>
Think through the necessary aspects such a prompt should cover, including functional requirements, integrations, and use interactions.""" 
payload1 = create_payload(target="ollama",
                         model=MODEL_PRESET, 
                         prompt=PROMPT1, 
                         temperature=1.0, 
                         num_ctx=100, 
                         num_predict=700)
time1, response1 = model_req(payload=payload1)
print(f'First response: {response1}')
if time1: print(f'Time taken: {time1}s')
PROMPT2 = response1

#### (3) Configure the Model request, simulating Workflow Orchestration
# Documentation: https://github.com/ollama/ollama/blob/main/docs/api.md
payload2 = create_payload(target="ollama",
                         model=MODEL_PRESET, 
                         prompt=PROMPT2, 
                         temperature=1.0, 
                         num_ctx=700, 
                         num_predict=700)

# Send out to the model
time2, response2 = model_req(payload=payload2)
print(f'Final response: {response2}')
if time2: print(f'Time taken: {time2}s')
# Out:
# {'model': 'qwen2.5:32b', 'prompt': 'Generate the best possible prompt for an LLM to perform a requirement analysis of the following use case: <An AI-powered Discord chatbot to serve as a learning companion in a classroom. \nThe bot will act as a study buddy by handling Q&A, explanations, and study tips. \nIt should leverage natural language understanding and domain-specific knowledge to assist students. \nThe bot must also be designed to prevent students from using it for cheating.>\nThink through the necessary aspects such a prompt should cover, including functional requirements, integrations, and use interactions.', 'stream': False, 'options': {'temperature': 1.0, 'num_ctx': 100, 'num_predict': 700}}
# First response: To design an educational chatbot that can help students with their studies while preventing them from misusing it for cheating, we need to consider several key aspects: functionality, security measures against cheating, integration with educational platforms, user experience, and compliance with ethical standards.
#
# ### Key Features
#
# 1. **Q&A Interaction**: The bot should be able to handle a wide range of questions related to different subjects and academic levels.
# 2. **Educational Content Delivery**: Provide explanations, step-by-step solutions, examples, and references for further reading.
# 3. **Adaptive Learning Paths**: Tailor responses based on the user's level of understanding and provide appropriate resources or simplifications if necessary.
# 4. **Interactive Tutorials**: Offer interactive quizzes, exercises, and problem sets to reinforce learning.
#
# ### Development Plan
#
# #### 1. Requirement Gathering
# - Identify target audience (e.g., high school students, university students)
# - Determine core subjects and topics (mathematics, science, programming)
#
# #### 2. Technology Stack
# - Frontend: React.js or Vue.js for web development; Flutter/Dart or SwiftUI for mobile app development
# - Backend: Node.js with Express.js, Django, or Flask
# - Database: PostgreSQL, MongoDB, Firebase
#
# #### 3. Core Features
#
# **1. Interactive Learning Modules**
#    - **Course Structure**: Organize content into courses and lessons.
#    - **Interactive Tutorials**: Use code editors for programming courses to allow live coding within the platform.
#      ```html
#      <div id="editor" style="height:400px;width:800px;"></div>
#      <script src="https://cdnjs.cloudflare.com/ajax/libs/ace/1.4.7/ace.js"></script>
#      <script>
#        var editor = ace.edit("editor");
#        editor.setTheme("ace/theme/twilight");
#        editor.session.setMode("ace/mode/javascript");
#      </script>
#    ```
#
# 5. **使用Ace Editor进行代码编辑**：
#    Ace Editor提供了丰富的API来操作代码，例如获取当前选中的文本、插入代码等。
#
# 6. **自定义主题和语法高亮**：
#    可以通过引入不同的样式表来自定义主题。例如，引入一个名为`theme-twilight.css`的样式表来改变主题：
#
#    ```html
#    <link href="theme-twilight.css" type="text/css" rel="stylesheet">
#    ```
#
# 5. **事件监听和操作代码**：
#    可以添加事件监听器来响应用户在代码编辑区域的操作。例如，当内容发生变化时执行某些操作。
#
# ```javascript
# editor.on("change", function() {
#     console.log(editor.getValue());
# });
# ```
#
# 6. **保存/加载代码**：
#    实现功能允许用户保存当前代码或从文件中加载代码。可以使用本地存储或与后端服务器进行交互来实现这些功能。
#
# ```html
# <!-- 添加一些简单的HTML按钮 -->
# <button onclick="saveCode()">保存</button>
# <button onclick="loadCode()">打开</button>
#
# <script type="text/javascript">
# function saveCode() {
#   const code = editor.getValue();
#   localStorage.setItem('code', code);
# }
#
# function loadCode() {
#   const savedCode = localStorage.getItem('code') || '';
#   editor.setValue(savedCode);
# }
# </script>
# ```
#
# ### 完整代码
# ```html
# <!DOCTYPE html>
# <html lang="en">
# <head>
#
# Time taken: 151.341s
# {'model': 'qwen2.5:32b', 'prompt': 'To design an educational chatbot that can help students with their studies while preventing them from misusing it for cheating, we need to consider several key aspects: functionality, security measures against cheating, integration with educational platforms, user experience, and compliance with ethical standards.\n\n### Key Features\n\n1. **Q&A Interaction**: The bot should be able to handle a wide range of questions related to different subjects and academic levels.\n2. **Educational Content Delivery**: Provide explanations, step-by-step solutions, examples, and references for further reading.\n3. **Adaptive Learning Paths**: Tailor responses based on the user\'s level of understanding and provide appropriate resources or simplifications if necessary.\n4. **Interactive Tutorials**: Offer interactive quizzes, exercises, and problem sets to reinforce learning.\n\n### Development Plan\n\n#### 1. Requirement Gathering\n- Identify target audience (e.g., high school students, university students)\n- Determine core subjects and topics (mathematics, science, programming)\n\n#### 2. Technology Stack\n- Frontend: React.js or Vue.js for web development; Flutter/Dart or SwiftUI for mobile app development\n- Backend: Node.js with Express.js, Django, or Flask\n- Database: PostgreSQL, MongoDB, Firebase\n\n#### 3. Core Features\n\n**1. Interactive Learning Modules**\n   - **Course Structure**: Organize content into courses and lessons.\n   - **Interactive Tutorials**: Use code editors for programming courses to allow live coding within the platform.\n     ```html\n     <div id="editor" style="height:400px;width:800px;"></div>\n     <script src="https://cdnjs.cloudflare.com/ajax/libs/ace/1.4.7/ace.js"></script>\n     <script>\n       var editor = ace.edit("editor");\n       editor.setTheme("ace/theme/twilight");\n       editor.session.setMode("ace/mode/javascript");\n     </script>\n   ```\n\n5. **使用Ace Editor进行代码编辑**：\n   Ace Editor提供了丰富的API来操作代码，例如获取当前选中的文本、插入代码等。\n\n6. **自定义主题和语法高亮**：\n   可以通过引入不同的样式表来自定义主题。例如，引入一个名为`theme-twilight.css`的样式表来改变主题：\n\n   ```html\n   <link href="theme-twilight.css" type="text/css" rel="stylesheet">\n   ```\n\n5. **事件监听和操作代码**：\n   可以添加事件监听器来响应用户在代码编辑区域的操作。例如，当内容发生变化时执行某些操作。\n\n```javascript\neditor.on("change", function() {\n    console.log(editor.getValue());\n});\n```\n\n6. **保存/加载代码**：\n   实现功能允许用户保存当前代码或从文件中加载代码。可以使用本地存储或与后端服务器进行交互来实现这些功能。\n   \n```html\n<!-- 添加一些简单的HTML按钮 -->\n<button onclick="saveCode()">保存</button>\n<button onclick="loadCode()">打开</button>\n\n<script type="text/javascript">\nfunction saveCode() {\n  const code = editor.getValue();\n  localStorage.setItem(\'code\', code);\n}\n\nfunction loadCode() {\n  const savedCode = localStorage.getItem(\'code\') || \'\';\n  editor.setValue(savedCode);\n}\n</script>\n```\n\n### 完整代码\n```html\n<!DOCTYPE html>\n<html lang="en">\n<head>\n', 'stream': False, 'options': {'temperature': 1.0, 'num_ctx': 700, 'num_predict': 700}}
# Final response: Here is the complete implementation for integrating an interactive code editor using Ace Editor in your web application. The example includes setting up a basic theme, syntax highlighting, and event handling to save and load code from local storage.
#
# ```html
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <title>Ace Editor Example</title>
#     <!-- Include Ace Editor CSS -->
#     <link href="https://cdnjs.cloudflare.com/ajax/libs/ace/1.4.12/ace.min.css" rel="stylesheet">
#     <!-- Include Ace Editor JavaScript -->
#     <script src="https://cdnjs.cloudflare.com/ajax/libs/ace/1.4.12/ace.min.js"></script>
# </head>
# <body>
#     <div id="editor" style="width: 800px; height: 600px;"></div>
#
#     <!-- Buttons to save and load code -->
#     <button onclick="saveCode()">保存</button>
#     <button onclick="loadCode()">打开</button>
#
#     <script type="text/javascript">
#         var editor = ace.edit("editor");
#         editor.setTheme("ace/theme/twilight"); // 设置主题
#         editor.session.setMode("ace/mode/javascript"); // 设置语法高亮
#
#         function saveCode() {
#             const code = editor.getValue(); // 获取编辑器中的代码
#             localStorage.setItem('code', code); // 保存到本地存储
#         }
#
#         function loadCode() {
#             const savedCode = localStorage.getItem('code') || ''; // 从本地存储加载代码
#             editor.setValue(savedCode); // 设置编辑器中的代码
#         }
#     </script>
# </body>
# </html>
# ```
#
# ### Explanation:
# 1. **Including Ace Editor**:
#    - We include the CSS and JavaScript files for Ace Editor from a CDN.
#
# 2. **Setting Up the Editor**:
#    - The editor is set up in a `div` with the id `"editor"`.
#    - A theme (`twilight`) and mode (`javascript`) are set to give it an appearance and provide syntax highlighting.
#
# 3. **Saving and Loading Code**:
#    - We define two functions: `saveCode()` and `loadCode()`.
#    - `saveCode()` retrieves the current code from the editor using `editor.getValue()` and saves it in local storage.
#    - `loadCode()` retrieves any saved code from local storage and sets it back into the editor with `editor.setValue()`.
#
# ### Usage:
# - When you press the "保存" button, the content of the editor will be saved to your browser's local storage.
# - When you press the "打开" button, the previously saved content (if any) will be loaded back into the editor.
#
# This setup provides a simple but powerful way to incorporate an interactive code editor into your web application. You can extend this by adding more features like different modes for other programming languages or additional UI elements for user interaction.
# Time taken: 127.671s

# %%
#### (OPTIONAL) LOGGING DATA TO CSV
# Define CSV file path
csv_file = "model_logs.csv"
# Log details
log_data = {
    "log_timestamp": timer.strftime("%Y-%m-%d %H:%M:%S"),
    "prompt_method": "Meta Prompting",
    "automation_level": 1,
    "model_1": payload1.get("model", None),
    "prompt_1": payload1.get("prompt", None),
    "temperature_1": payload1.get("options", {}).get("temperature", None),  
    "num_ctx_1": payload1.get("options", {}).get("num_ctx", None),         
    "num_predict_1": payload1.get("options", {}).get("num_predict", None),  
    "response_time_1": time1,
    "response_1": response1,
    "model_2": payload2.get("model", None),
    "prompt_2": payload2.get("prompt", None),
    "temperature_2": payload2.get("options", {}).get("temperature", None),  
    "num_ctx_2": payload2.get("options", {}).get("num_ctx", None),             
    "num_predict_2": payload2.get("options", {}).get("num_predict", None),  
    "response_time_2": time2,
    "response_2": response2,
    "model_3": None,
    "prompt_3": None,
    "temperature_3": None,  
    "num_ctx_3": None,         
    "num_predict_3": None,  
    "response_time_3": None,
    "response_3": None,
    "model_4": None,
    "prompt_4": None,
    "temperature_4": None,  
    "num_ctx_4": None,         
    "num_predict_4": None,  
    "response_time_4": None,
    "response_4": None,
}
# Save to CSV file
write_header = False
try:
    with open(csv_file, "r") as f:
        if not f.read():
            write_header = True
except FileNotFoundError:
    write_header = True
with open(csv_file, "a", newline="", encoding="utf-8") as f:
    writer = csv.DictWriter(f, fieldnames=log_data.keys())
    if write_header:
        writer.writeheader()
    writer.writerow(log_data)
# Print confirmation
print(f"Logged data to {csv_file} for {MODEL_PRESET} model.")
# Out:
# Logged data to model_logs.csv for qwen2.5:32b model.
